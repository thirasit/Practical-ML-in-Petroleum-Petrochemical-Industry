# %% [markdown]
# # **Fancyimpute Missing Data**

# %%
# !pip install fancyimpute
# Out:
# Collecting fancyimpute
#   Downloading fancyimpute-0.7.0.tar.gz (25 kB)
# Collecting knnimpute>=0.1.0
#   Downloading knnimpute-0.1.0.tar.gz (8.3 kB)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (1.0.1)
# Requirement already satisfied: cvxpy in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (1.0.31)
# Requirement already satisfied: cvxopt in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (1.2.7)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from fancyimpute) (3.6.4)
# Collecting nose
#   Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#      |████████████████████████████████| 154 kB 6.3 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from knnimpute>=0.1.0->fancyimpute) (1.15.0)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.7/dist-packages (from knnimpute>=0.1.0->fancyimpute) (1.19.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->fancyimpute) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->fancyimpute) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.2->fancyimpute) (1.1.0)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.7/dist-packages (from cvxpy->fancyimpute) (2.0.7.post1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from cvxpy->fancyimpute) (0.70.12.2)
# Requirement already satisfied: scs>=1.1.3 in /usr/local/lib/python3.7/dist-packages (from cvxpy->fancyimpute) (2.1.4)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from cvxpy->fancyimpute) (0.6.2.post0)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.7/dist-packages (from osqp>=0.4.1->cvxpy->fancyimpute) (0.1.5.post0)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.7/dist-packages (from multiprocess->cvxpy->fancyimpute) (0.3.4)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (1.4.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (0.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (21.2.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (8.12.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (1.11.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytest->fancyimpute) (57.4.0)
# Building wheels for collected packages: fancyimpute, knnimpute
#   Building wheel for fancyimpute (setup.py) ... done
#   Created wheel for fancyimpute: filename=fancyimpute-0.7.0-py3-none-any.whl size=29899 sha256=4e482a4bdea1a628d1b79c4486f8d368f7fea1664a67b2061ed1eef5813510f9
#   Stored in directory: /root/.cache/pip/wheels/e3/04/06/a1a7d89ef4e631ce6268ea2d8cde04f7290651c1ff1025ce68
#   Building wheel for knnimpute (setup.py) ... done
#   Created wheel for knnimpute: filename=knnimpute-0.1.0-py3-none-any.whl size=11353 sha256=8d167a8517d2695b0ee58c71ccd19012a225abd5491009d71c5ca4f6f120e4ce
#   Stored in directory: /root/.cache/pip/wheels/72/21/a8/a045cacd9838abd5643f6bfa852c0796a99d6b1494760494e0
# Successfully built fancyimpute knnimpute
# Installing collected packages: nose, knnimpute, fancyimpute
# Successfully installed fancyimpute-0.7.0 knnimpute-0.1.0 nose-1.3.7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
# %matplotlib inline
from fancyimpute import KNN, NuclearNormMinimization, SoftImpute, IterativeImputer, BiScaler
from fancyimpute import IterativeImputer

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ea8a462d-c8bc-4715-8995-1da61d9b9f35" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea8a462d-c8bc-4715-8995-1da61d9b9f35">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Imputation_DataSet.xlsx to Imputation_DataSet.xlsx

# %%
df=pd.read_excel('Imputation_DataSet.xlsx')

# %%
df.head(2)
# Out:
#    Surface Treating Pressure  Slurry Rate  Proppant Concentration
# 0                     7913.0         64.4                     0.0
# 1                     8000.0         64.8                     0.0

# %%
missing_val_count_by_column = (df.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# Surface Treating Pressure    164
# dtype: int64

# %%
df.describe()
# Out:
#        Surface Treating Pressure  Slurry Rate  Proppant Concentration
# count                4588.000000  4752.000000             4752.000000
# mean                 8142.469922    99.710795                1.422033
# std                    85.671249     3.308136                0.703032
# min                  7913.000000    64.400000                0.000000
# 25%                  8088.000000    99.900000                1.000000
# 50%                  8116.000000   100.300000                1.500000
# 75%                  8193.000000   100.700000                2.000000
# max                  8708.000000   101.600000                3.500000

# %%
#Shows a heatmap of the missing values across the whole data set
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
missingdata_df=df.columns[df.isnull().any()].tolist()
msno.matrix(df[missingdata_df])

# %%
# Shows a bar chart of missing columns
msno.bar(df[missingdata_df], color="blue", log=True, figsize=(30,18))

# %%
df.columns
# Out:
# Index(['Surface Treating Pressure', 'Slurry Rate', 'Proppant Concentration'], dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df)
df_scaled=scaler.transform(df)
df_scaled=pd.DataFrame(df_scaled, columns=['Surface Treating Pressure', 'Slurry Rate', 'Proppant Concentration'])
df_scaled
# Out:
#       Surface Treating Pressure  Slurry Rate  Proppant Concentration
# 0                     -2.678786   -10.675047               -2.022926
# 1                     -1.663165   -10.554120               -2.022926
# 2                     -1.091149   -10.433193               -2.022926
# 3                     -0.717588   -10.282035               -2.022926
# 4                     -0.122224   -10.070413               -2.022926
# ...                         ...          ...                     ...
# 4747                  -0.682566    -0.003264               -2.022926
# 4748                  -0.659219     0.026968               -2.022926
# 4749                  -0.495785     0.057200               -2.022926
# 4750                  -0.554154     0.057200               -2.022926
# 4751                  -0.519133     0.057200               -2.022926
#
# [4752 rows x 3 columns]

# %%
df_scaled.describe()
# Out:
#        Surface Treating Pressure   Slurry Rate  Proppant Concentration
# count               4.588000e+03  4.752000e+03            4.752000e+03
# mean               -4.951454e-15 -1.846514e-15            1.456074e-14
# std                 1.000109e+00  1.000105e+00            1.000105e+00
# min                -2.678786e+00 -1.067505e+01           -2.022926e+00
# 25%                -6.358710e-01  5.719971e-02           -6.003667e-01
# 50%                -3.090046e-01  1.781264e-01            1.109129e-01
# 75%                 5.898780e-01  2.990532e-01            8.221926e-01
# max                 6.601885e+00  5.711383e-01            2.956032e+00

# %%
# Use # nearest rows which have a feature to fill in each row's missing features
X_filled_knn = KNN(k=2).fit_transform(df_scaled)
X_filled_knn=pd.DataFrame(X_filled_knn,columns=['Surface Treating Pressure', 'Slurry Rate', 'Proppant Concentration'])
X_filled_knn
# Out:
# Imputing row 1/4752 with 0 missing, elapsed time: 2.862
# Imputing row 101/4752 with 0 missing, elapsed time: 2.863
# Imputing row 201/4752 with 0 missing, elapsed time: 2.863
# Imputing row 301/4752 with 0 missing, elapsed time: 2.866
# Imputing row 401/4752 with 0 missing, elapsed time: 2.867
# Imputing row 501/4752 with 0 missing, elapsed time: 2.867
# Imputing row 601/4752 with 0 missing, elapsed time: 2.867
# Imputing row 701/4752 with 0 missing, elapsed time: 2.868
# Imputing row 801/4752 with 0 missing, elapsed time: 2.868
# Imputing row 901/4752 with 0 missing, elapsed time: 2.868
# Imputing row 1001/4752 with 0 missing, elapsed time: 2.869
# Imputing row 1101/4752 with 0 missing, elapsed time: 2.870
# Imputing row 1201/4752 with 0 missing, elapsed time: 2.871
# Imputing row 1301/4752 with 0 missing, elapsed time: 2.871
# Imputing row 1401/4752 with 0 missing, elapsed time: 2.871
# Imputing row 1501/4752 with 0 missing, elapsed time: 2.871
# Imputing row 1601/4752 with 0 missing, elapsed time: 2.872
# Imputing row 1701/4752 with 0 missing, elapsed time: 2.872
# Imputing row 1801/4752 with 0 missing, elapsed time: 2.872
# Imputing row 1901/4752 with 0 missing, elapsed time: 2.873
# Imputing row 2001/4752 with 0 missing, elapsed time: 2.873
# Imputing row 2101/4752 with 1 missing, elapsed time: 2.880
# Imputing row 2201/4752 with 0 missing, elapsed time: 2.882
# Imputing row 2301/4752 with 0 missing, elapsed time: 2.883
# Imputing row 2401/4752 with 0 missing, elapsed time: 2.883
# Imputing row 2501/4752 with 0 missing, elapsed time: 2.883
# Imputing row 2601/4752 with 0 missing, elapsed time: 2.885
# Imputing row 2701/4752 with 0 missing, elapsed time: 2.885
# Imputing row 2801/4752 with 0 missing, elapsed time: 2.886
# Imputing row 2901/4752 with 0 missing, elapsed time: 2.886
# Imputing row 3001/4752 with 0 missing, elapsed time: 2.886
# Imputing row 3101/4752 with 0 missing, elapsed time: 2.887
# Imputing row 3201/4752 with 0 missing, elapsed time: 2.887
# Imputing row 3301/4752 with 0 missing, elapsed time: 2.887
# Imputing row 3401/4752 with 0 missing, elapsed time: 2.888
# Imputing row 3501/4752 with 0 missing, elapsed time: 2.888
# Imputing row 3601/4752 with 0 missing, elapsed time: 2.888
# Imputing row 3701/4752 with 0 missing, elapsed time: 2.889
# Imputing row 3801/4752 with 0 missing, elapsed time: 2.889
# Imputing row 3901/4752 with 0 missing, elapsed time: 2.889
# Imputing row 4001/4752 with 0 missing, elapsed time: 2.890
# Imputing row 4101/4752 with 0 missing, elapsed time: 2.890
# Imputing row 4201/4752 with 0 missing, elapsed time: 2.890
# Imputing row 4301/4752 with 0 missing, elapsed time: 2.891
# Imputing row 4401/4752 with 0 missing, elapsed time: 2.891
# Imputing row 4501/4752 with 0 missing, elapsed time: 2.891
# Imputing row 4601/4752 with 0 missing, elapsed time: 2.892
# Imputing row 4701/4752 with 1 missing, elapsed time: 2.902
#       Surface Treating Pressure  Slurry Rate  Proppant Concentration
# 0                     -2.678786   -10.675047               -2.022926
# 1                     -1.663165   -10.554120               -2.022926
# 2                     -1.091149   -10.433193               -2.022926
# 3                     -0.717588   -10.282035               -2.022926
# 4                     -0.122224   -10.070413               -2.022926
# ...                         ...          ...                     ...
# 4747                  -0.682566    -0.003264               -2.022926
# 4748                  -0.659219     0.026968               -2.022926
# 4749                  -0.495785     0.057200               -2.022926
# 4750                  -0.554154     0.057200               -2.022926
# 4751                  -0.519133     0.057200               -2.022926
#
# [4752 rows x 3 columns]

# %%
X_filled_knn['Surface Treating Pressure']=(X_filled_knn['Surface Treating Pressure']*df['Surface Treating Pressure'].std())+df['Surface Treating Pressure'].mean()
X_filled_knn['Slurry Rate']=(X_filled_knn['Slurry Rate']*df['Slurry Rate'].std())+df['Slurry Rate'].mean()
X_filled_knn['Proppant Concentration']=(X_filled_knn['Proppant Concentration']*df['Proppant Concentration'].std())+df['Proppant Concentration'].mean()

# %%
X_filled_knn
# Out:
#       Surface Treating Pressure  Slurry Rate  Proppant Concentration
# 0                   7912.974988    64.396284                -0.00015
# 1                   7999.984471    64.796326                -0.00015
# 2                   8048.989812    65.196368                -0.00015
# 3                   8080.993300    65.696421                -0.00015
# 4                   8131.998859    66.396495                -0.00015
# ...                         ...          ...                     ...
# 4747                8083.993627    99.699999                -0.00015
# 4748                8085.993845    99.800009                -0.00015
# 4749                8099.995371    99.900020                -0.00015
# 4750                8094.994826    99.900020                -0.00015
# 4751                8097.995153    99.900020                -0.00015
#
# [4752 rows x 3 columns]

# %%
X_filled_knn.to_csv('KNN_Imputation.csv', index=False)

# %% [markdown]
# ## **Applying MICE**

# %%
# !pip install impyute
# Out:
# Collecting impyute
#   Downloading impyute-0.0.8-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from impyute) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from impyute) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from impyute) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->impyute) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->impyute) (1.1.0)
# Installing collected packages: impyute
# Successfully installed impyute-0.0.8

# %%
#Appying MICE Imputations
from impyute.imputation.cs import mice
imputed_training=mice(df_scaled.values)
imputed_training=pd.DataFrame(imputed_training,columns=['Surface Treating Pressure', 'Slurry Rate', 'Proppant Concentration'])

# %%
imputed_training['Surface Treating Pressure']=(imputed_training['Surface Treating Pressure']*df['Surface Treating Pressure'].std())+df['Surface Treating Pressure'].mean()
imputed_training['Slurry Rate']=(imputed_training['Slurry Rate']*df['Slurry Rate'].std())+df['Slurry Rate'].mean()
imputed_training['Proppant Concentration']=(imputed_training['Proppant Concentration']*df['Proppant Concentration'].std())+df['Proppant Concentration'].mean()

# %%
imputed_training
# Out:
#       Surface Treating Pressure  Slurry Rate  Proppant Concentration
# 0                   7912.974988    64.396284                -0.00015
# 1                   7999.984471    64.796326                -0.00015
# 2                   8048.989812    65.196368                -0.00015
# 3                   8080.993300    65.696421                -0.00015
# 4                   8131.998859    66.396495                -0.00015
# ...                         ...          ...                     ...
# 4747                8083.993627    99.699999                -0.00015
# 4748                8085.993845    99.800009                -0.00015
# 4749                8099.995371    99.900020                -0.00015
# 4750                8094.994826    99.900020                -0.00015
# 4751                8097.995153    99.900020                -0.00015
#
# [4752 rows x 3 columns]

# %%
imputed_training.to_csv('MICE_Imputation.csv', index=False)

# %%
df.columns
# Out:
# Index(['Surface Treating Pressure', 'Slurry Rate', 'Proppant Concentration'], dtype='object')

# %% [markdown]
# ## **Iterative imputer**

# %%
from fancyimpute import IterativeImputer

# %%
#Model each feature with missing values as a function of other features, and use that estimate for imputation.
X_filled_ii = IterativeImputer(max_iter=10).fit_transform(df_scaled)
X_filled_ii=pd.DataFrame(X_filled_ii,columns=['Surface Treating Pressure', 'Slurry Rate', 'Proppant Concentration'])

# %%
X_filled_ii['Surface Treating Pressure']=(X_filled_ii['Surface Treating Pressure']*df['Surface Treating Pressure'].std())+df['Surface Treating Pressure'].mean()
X_filled_ii['Slurry Rate']=(X_filled_ii['Slurry Rate']*df['Slurry Rate'].std())+df['Slurry Rate'].mean()
X_filled_ii['Proppant Concentration']=(X_filled_ii['Proppant Concentration']*df['Proppant Concentration'].std())+df['Proppant Concentration'].mean()

# %%
X_filled_ii.to_csv('Iterative_Imputer_Imputation.csv', index=False)

# %% [markdown]
# ## **Applying iterative imputer 5 times**

# %%
#Applying iterative imputer 5 times and taking the mean
from fancyimpute import IterativeImputer
XY_incomplete = df_scaled

n_imputations = 5
XY_completed = []
for i in range(n_imputations):
    imputer = IterativeImputer(sample_posterior=True, random_state=i)
    XY_completed.append(imputer.fit_transform(XY_incomplete))

XY_completed_mean = np.mean(XY_completed, 0)
XY_completed_std = np.std(XY_completed, 0)

XY_completed=np.array(XY_completed)
XY_completed_mean=pd.DataFrame(XY_completed_mean,columns=['Surface Treating Pressure', 'Slurry Rate', 'Proppant Concentration'])

# %%
XY_completed_mean['Surface Treating Pressure']=(XY_completed_mean['Surface Treating Pressure']*df['Surface Treating Pressure'].std())+df['Surface Treating Pressure'].mean()
XY_completed_mean['Slurry Rate']=(XY_completed_mean['Slurry Rate']*df['Slurry Rate'].std())+df['Slurry Rate'].mean()
XY_completed_mean['Proppant Concentration']=(XY_completed_mean['Proppant Concentration']*df['Proppant Concentration'].std())+df['Proppant Concentration'].mean()

# %%
XY_completed_mean.to_csv('Mean_Iterative_Imputer.csv', index=False)
