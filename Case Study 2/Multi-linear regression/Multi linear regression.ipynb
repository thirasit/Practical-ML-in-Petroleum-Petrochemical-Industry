# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-224e9eb3-c356-43c6-975d-528a23c83a5c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-224e9eb3-c356-43c6-975d-528a23c83a5c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Geologic_DataSet.csv to Geologic_DataSet.csv

# %%
df=pd.read_csv('Geologic_DataSet.csv')

# %%
df.head()
# Out:
#    Porosity (%)  Matrix Perm (nd)  ...  Vitrinite Reflectance (%)   Aroot(K)
# 0         8.456               292  ...                      1.848  48.306469
# 1         8.666               353  ...                      1.504  41.300912
# 2         9.814               259  ...                      2.176  49.688356
# 3        12.369               675  ...                      1.504  59.132694
# 4        12.264               457  ...                      1.520  39.503121
#
# [5 rows x 7 columns]

# %%
df.describe().transpose()
# Out:
#                                   count        mean  ...         75%         max
# Porosity (%)                      200.0   10.493805  ...   12.181750   16.485000
# Matrix Perm (nd)                  200.0  433.075000  ...  528.750000  987.000000
# Acoustic impedance (kg/m2s*10^6)  200.0    3.265735  ...    3.679500    5.093000
# Brittleness Ratio                 200.0   57.794340  ...   69.915000  101.196000
# TOC (%)                           200.0    3.970700  ...    5.400000    8.720000
# Vitrinite Reflectance (%)         200.0    1.571440  ...    1.714000    2.296000
# Aroot(K)                          200.0   50.000000  ...   58.986667   77.270733
#
# [7 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Porosity (%)', 'Matrix Perm (nd)', 'Acoustic impedance (kg/m2s*10^6)',
#        'Brittleness Ratio', 'TOC (%)', 'Vitrinite Reflectance (%)',
#        'Aroot(K)'],
#       dtype='object')

# %%
f, axes = plt.subplots(4, 2, figsize=(12, 12))
sns.distplot(df['Porosity (%)'] , color="red", ax=axes[0, 0])
sns.distplot(df['Matrix Perm (nd)'] , color="olive", ax=axes[0, 1])
sns.distplot(df['Acoustic impedance (kg/m2s*10^6)'] , color="blue", ax=axes[1, 0])
sns.distplot(df['Brittleness Ratio'] , color="orange", ax=axes[1, 1])
sns.distplot(df['TOC (%)'] , color="black", ax=axes[2, 0])
sns.distplot(df['Vitrinite Reflectance (%)'] , color="green", ax=axes[2, 1])
sns.distplot(df['Aroot(K)'] , color="cyan", ax=axes[3, 0])

plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f, axes = plt.subplots(4, 2, figsize=(12, 12))
sns.boxplot(df['Porosity (%)'] , color="red", ax=axes[0, 0])
sns.boxplot(df['Matrix Perm (nd)'] , color="olive", ax=axes[0, 1])
sns.boxplot(df['Acoustic impedance (kg/m2s*10^6)'] , color="blue", ax=axes[1, 0])
sns.boxplot(df['Brittleness Ratio'] , color="orange", ax=axes[1, 1])
sns.boxplot(df['TOC (%)'] , color="black", ax=axes[2, 0])
sns.boxplot(df['Vitrinite Reflectance (%)'] , color="green", ax=axes[2, 1])
sns.boxplot(df['Aroot(K)'] , color="cyan", ax=axes[3, 0])

plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
f, axes = plt.subplots(3, 2, figsize=(12, 12))
sns.scatterplot(df['Porosity (%)'] ,df['Aroot(K)'], color="red", ax=axes[0, 0])
sns.scatterplot(df['Matrix Perm (nd)'] ,df['Aroot(K)'], color="olive", ax=axes[0, 1])
sns.scatterplot(df['Acoustic impedance (kg/m2s*10^6)'] , df['Aroot(K)'],color="blue", ax=axes[1, 0])
sns.scatterplot(df['Brittleness Ratio'] , df['Aroot(K)'],color="orange", ax=axes[1, 1])
sns.scatterplot(df['TOC (%)'] , df['Aroot(K)'],color="black", ax=axes[2, 0])
sns.scatterplot(df['Vitrinite Reflectance (%)'] ,df['Aroot(K)'], color="green", ax=axes[2, 1])

plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(),linewidths=2, linecolor='black',cmap='viridis', annot=True)

# %%
df.drop(['TOC (%)', 'Matrix Perm (nd)'], axis=1, inplace=True)

# %%
df
# Out:
#      Porosity (%)  ...   Aroot(K)
# 0           8.456  ...  48.306469
# 1           8.666  ...  41.300912
# 2           9.814  ...  49.688356
# 3          12.369  ...  59.132694
# 4          12.264  ...  39.503121
# ..            ...  ...        ...
# 195         8.365  ...  44.622765
# 196        12.593  ...  64.961047
# 197         8.484  ...  39.543047
# 198        10.885  ...  59.004091
# 199        14.623  ...  77.270733
#
# [200 rows x 5 columns]

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(),linewidths=2, linecolor='black',cmap='viridis', annot=True)

# %%
from sklearn import preprocessing
scaler=preprocessing.MinMaxScaler(feature_range=(0,1))
scaler.fit(df)
df_scaled=scaler.transform(df)
df_scaled
# Out:
# array([[0.32529412, 0.45373134, 0.9600763 , 0.71134021, 0.45177576],
#        [0.34294118, 0.57910448, 0.48003815, 0.48969072, 0.31917731],
#        [0.43941176, 0.81492537, 0.84289413, 0.92268041, 0.47793158],
#        [0.65411765, 0.40298507, 0.39337784, 0.48969072, 0.65669029],
#        [0.64529412, 0.56716418, 0.        , 0.5       , 0.28514944],
#        [0.46941176, 0.42089552, 0.5812781 , 0.3814433 , 0.50238885],
#        [0.40823529, 0.49253731, 0.71903529, 0.4742268 , 0.43843026],
#        [0.29588235, 0.5880597 , 0.5731026 , 0.51546392, 0.30503973],
#        [0.35117647, 0.34328358, 0.74710451, 0.54123711, 0.42118734],
#        [0.39411765, 0.72537313, 0.75296362, 0.88659794, 0.47808031],
#        [0.49941176, 0.28059701, 0.68360812, 0.43298969, 0.56731787],
#        [0.56705882, 0.30149254, 0.51996185, 0.47938144, 0.66317086],
#        [0.60411765, 0.45373134, 0.75909524, 0.54123711, 0.66004008],
#        [0.63764706, 0.37910448, 0.61983922, 0.64948454, 0.75497868],
#        [0.42823529, 0.36716418, 0.75323614, 0.36597938, 0.48654097],
#        [0.28176471, 0.64179104, 0.64164055, 0.62886598, 0.31453193],
#        [0.76470588, 0.53731343, 0.33451424, 0.5257732 , 0.72852016],
#        [0.53117647, 0.37313433, 0.25194168, 0.48969072, 0.37073953],
#        [0.48117647, 0.52238806, 0.76958714, 0.54123711, 0.5328626 ],
#        [0.34823529, 0.67462687, 0.51614661, 0.82989691, 0.37235832],
#        [0.67823529, 0.32835821, 0.58073307, 0.59793814, 0.80599842],
#        [0.57470588, 0.33731343, 0.48834991, 0.40721649, 0.58482678],
#        [0.35705882, 0.32835821, 0.06458646, 0.28350515, 0.08318242],
#        [0.20470588, 0.6       , 0.36517237, 0.39690722, 0.08962854],
#        [0.71235294, 0.03283582, 0.57787164, 0.40206186, 0.86469824],
#        [0.41      , 0.64776119, 0.28110097, 0.66494845, 0.28541478],
#        [0.        , 0.85074627, 0.62338193, 0.60309278, 0.01770065],
#        [0.81294118, 0.32537313, 0.36544488, 0.54639175, 0.83243336],
#        [0.37470588, 0.71641791, 0.82381796, 0.50515464, 0.3838871 ],
#        [0.62235294, 0.47761194, 0.55198256, 0.69587629, 0.74247929],
#        [0.31764706, 0.50447761, 0.76631694, 0.58247423, 0.38205205],
#        [0.67294118, 0.62686567, 0.45483036, 0.59278351, 0.76700709],
#        [0.32764706, 0.66865672, 0.62855975, 0.41237113, 0.28590513],
#        [0.52941176, 0.35820896, 0.64463823, 0.73195876, 0.65425615],
#        [0.84352941, 0.58208955, 0.48003815, 0.69072165, 1.        ]])

# %%
df.columns
# Out:
# Index(['Porosity (%)', 'Acoustic impedance (kg/m2s*10^6)', 'Brittleness Ratio',
#        'Vitrinite Reflectance (%)', 'Aroot(K)'],
#       dtype='object')

# %%
df_scaled=pd.DataFrame(df_scaled, columns=['Porosity (%)', 'Acoustic impedance (kg/m2s*10^6)',
       'Brittleness Ratio', 'Vitrinite Reflectance (%)', 'Aroot(K)'])

df_scaled
# Out:
#      Porosity (%)  ...  Aroot(K)
# 0        0.325294  ...  0.451776
# 1        0.342941  ...  0.319177
# 2        0.439412  ...  0.477932
# 3        0.654118  ...  0.656690
# 4        0.645294  ...  0.285149
# ..            ...  ...       ...
# 195      0.317647  ...  0.382052
# 196      0.672941  ...  0.767007
# 197      0.327647  ...  0.285905
# 198      0.529412  ...  0.654256
# 199      0.843529  ...  1.000000
#
# [200 rows x 5 columns]

# %%
y_scaled=df_scaled['Aroot(K)']
x_scaled=df_scaled.drop(['Aroot(K)'], axis=1)

x_scaled
# Out:
#      Porosity (%)  ...  Vitrinite Reflectance (%)
# 0        0.325294  ...                   0.711340
# 1        0.342941  ...                   0.489691
# 2        0.439412  ...                   0.922680
# 3        0.654118  ...                   0.489691
# 4        0.645294  ...                   0.500000
# ..            ...  ...                        ...
# 195      0.317647  ...                   0.582474
# 196      0.672941  ...                   0.592784
# 197      0.327647  ...                   0.412371
# 198      0.529412  ...                   0.731959
# 199      0.843529  ...                   0.690722
#
# [200 rows x 4 columns]

# %%
y_scaled
# Out:
# 0      0.451776
# 1      0.319177
# 2      0.477932
# 3      0.656690
# 4      0.285149
#          ...
# 195    0.382052
# 196    0.767007
# 197    0.285905
# 198    0.654256
# 199    1.000000
# Name: Aroot(K), Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
seed= 1000
np.random.seed(seed)
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y_scaled, test_size=0.3)

# %%
X_train
# Out:
#      Porosity (%)  ...  Vitrinite Reflectance (%)
# 44       0.695294  ...                   0.726804
# 101      0.401176  ...                   0.407216
# 25       0.042353  ...                   0.386598
# 3        0.654118  ...                   0.489691
# 68       0.487647  ...                   0.608247
# ..            ...  ...                        ...
# 94       0.541176  ...                   0.572165
# 192      0.812941  ...                   0.546392
# 71       0.448235  ...                   0.505155
# 87       0.490000  ...                   0.567010
# 179      0.039412  ...                   0.381443
#
# [140 rows x 4 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(seed)
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# -0.29565316262910474

# %%
coeff_df = pd.DataFrame(lm.coef_,x_scaled.columns,columns=['Coefficient'])
coeff_df
# Out:
#                                   Coefficient
# Porosity (%)                         1.069765
# Acoustic impedance (kg/m2s*10^6)    -0.178141
# Brittleness Ratio                    0.426330
# Vitrinite Reflectance (%)            0.231669

# %%
y_prediction=lm.predict(X_train)
plt.plot(y_prediction, y_train, 'b.')
plt.xlabel('Training Prediction')
plt.ylabel('Training Actual')
plt.title('Actual Vs. Predicted Training')
# Out:
# Text(0.5, 1.0, 'Actual Vs. Predicted Training')

# %%
plt.figure(figsize=(10,8))
y_pred = lm.predict(X_test)
plt.plot(y_test,y_pred, 'b.')
plt.xlabel('Testing Actuals')
plt.ylabel('Testing Predictions')
plt.title('Actual Vs. Predicted, Testing Data Set (30% of the data)')
# Out:
# Text(0.5, 1.0, 'Actual Vs. Predicted, Testing Data Set (30% of the data)')

# %%
from sklearn.metrics import r2_score
test_set_r2 = r2_score(y_test,y_pred)
print('Testing r^2:',round(test_set_r2,4))
# Out:
# Testing r^2: 0.9416

# %%
train_set_r2 = r2_score(y_prediction, y_train)
print('Train r^2:',round(train_set_r2,4))
# Out:
# Train r^2: 0.9427

# %%
y_test
# Out:
# 118    0.257136
# 70     0.235644
# 163    0.296721
# 161    0.518879
# 73     0.434727
# 96     0.696226
# 16     0.728520
# 120    0.582683
# 74     0.705596
# 143    0.239240
# 83     0.440350
# 127    0.591382
# 62     0.771328
# 122    0.851234
# 49     0.709037
# 157    0.604091
# 195    0.382052
# 152    0.768387
# 10     0.567318
# 184    0.485620
# 106    0.391460
# 37     0.689825
# 57     0.347865
# 15     0.314532
# 66     0.278597
# 141    0.472588
# 108    0.959942
# 172    0.202897
# 126    0.502201
# 154    0.270886
# 182    0.227067
# 191    0.017701
# 107    0.576630
# 98     0.343499
# 38     0.468094
# 39     0.518957
# 28     0.143420
# 80     0.537376
# 33     0.441467
# 165    0.673575
# 132    0.252691
# 167    0.236128
# 24     0.864698
# 125    0.545197
# 131    0.691540
# 171    0.733660
# 119    0.759742
# 110    0.509817
# 136    0.481416
# 173    0.297061
# 188    0.500183
# 22     0.083182
# 65     0.510323
# 159    0.832191
# 17     0.370740
# 64     0.771226
# 129    0.363473
# 178    0.828375
# 59     0.408830
# 103    0.384120
# Name: Aroot(K), dtype: float64

# %%
y_pred
# Out:
# array([ 0.25062133,  0.23853489,  0.28980651,  0.57064808,  0.47501024,
#         0.73159979,  0.6911037 ,  0.6337517 ,  0.70293214,  0.23064909,
#         0.50797282,  0.59381067,  0.72281046,  0.70591437,  0.68864771,
#         0.6055747 ,  0.4159314 ,  0.70330531,  0.580367  ,  0.58636922,
#         0.40233511,  0.70813068,  0.38156095,  0.3106789 ,  0.32077805,
#         0.45782537,  0.88961586,  0.18337738,  0.49182365,  0.34780657,
#         0.19233427, -0.04172157,  0.59758921,  0.27710327,  0.47146136,
#         0.57292579,  0.17677735,  0.55638183,  0.44903223,  0.70495631,
#         0.27571437,  0.24858081,  0.80005672,  0.56465753,  0.66431418,
#         0.71740351,  0.71181345,  0.63822219,  0.4467829 ,  0.30086048,
#         0.49896413,  0.12103637,  0.45395915,  0.729584  ,  0.42696677,
#         0.78317552,  0.46760066,  0.82497265,  0.41796024,  0.52616439])

# %%
plt.figure(figsize=(8,5))
sns.distplot((y_test-y_pred))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn import metrics

# %%
print('MAE:', round(metrics.mean_absolute_error(y_test, y_pred),5))
print('MSE:', round(metrics.mean_squared_error(y_test, y_pred),5))
print('RMSE:', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),5))
# Out:
# MAE: 0.03793
# MSE: 0.00266
# RMSE: 0.05159

# %%
import statsmodels.api as sm
X = sm.add_constant(X_train) # adding a constant
 
model = sm.OLS(y_train,X).fit()
predictions = model.predict(X) 
 
model_stats = model.summary()
print(model_stats)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Aroot(K)   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     589.0
# Date:                Fri, 07 Jan 2022   Prob (F-statistic):           2.26e-84
# Time:                        04:55:15   Log-Likelihood:                 218.23
# No. Observations:                 140   AIC:                            -426.5
# Df Residuals:                     135   BIC:                            -411.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                               -0.2957      0.030     -9.761      0.000      -0.356      -0.236
# Porosity (%)                         1.0698      0.035     30.654      0.000       1.001       1.139
# Acoustic impedance (kg/m2s*10^6)    -0.1781      0.040     -4.400      0.000      -0.258      -0.098
# Brittleness Ratio                    0.4263      0.027     16.083      0.000       0.374       0.479
# Vitrinite Reflectance (%)            0.2317      0.039      5.899      0.000       0.154       0.309
# ==============================================================================
# Omnibus:                        6.746   Durbin-Watson:                   2.148
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                9.002
# Skew:                          -0.252   Prob(JB):                       0.0111
# Kurtosis:                       4.136   Cond. No.                         20.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-424519ee-bae7-46f5-ab70-e6f7cd8fc367" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-424519ee-bae7-46f5-ab70-e6f7cd8fc367">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Geologic_Sensitivity_DataSet.xlsx to Geologic_Sensitivity_DataSet.xlsx

# %%
df_sensitivity=pd.read_excel('Geologic_Sensitivity_DataSet.xlsx')

# %%
df_sensitivity.describe().transpose()
# Out:
#                                   count       mean  ...   75%     max
# Porosity (%)                       69.0  10.500000  ...  10.5   16.50
# Acoustic impedance (kg/m2s*10^6)   69.0   3.223188  ...   3.3    5.00
# Brittleness Ratio                  69.0  58.855072  ...  59.0  103.00
# Vitrinite Reflectance (%)          69.0   1.505217  ...   1.5    2.34
# Aroot(K)                           69.0  50.000000  ...  50.0   50.00
#
# [5 rows x 8 columns]

# %%
scaled_sensitivity=scaler.transform(df_sensitivity)

print(scaled_sensitivity)
# Out:
# [[-0.00714286  0.49986431  0.52087024  0.4871134   0.48383024]
#  [ 0.07689076  0.49986431  0.52087024  0.4871134   0.48383024]
#  [ 0.16092437  0.49986431  0.52087024  0.4871134   0.48383024]
#  [ 0.24495798  0.49986431  0.52087024  0.4871134   0.48383024]
#  [ 0.3289916   0.49986431  0.52087024  0.4871134   0.48383024]
#  [ 0.41302521  0.49986431  0.52087024  0.4871134   0.48383024]
#  [ 0.49705882  0
  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.70339213,  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.73052917,  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.75766621,  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.78480326,  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.8119403 ,  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.83907734,  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.86621438,  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.89335142,  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.92048847,  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.94762551,  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.97476255,  0.52087024,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.49986431, -0.00145342,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.1120952 ,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.22564382,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.33919244,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.45274106,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.56628969,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.67983831,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.79338693,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.90693555,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.49986431,  1.02048417,  0.4871134 ,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.52087024, -0.00257732,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.52087024,  0.12628866,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.52087024,  0.25515464,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.52087024,  0.38402062,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.52087024,  0.5128866 ,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.52087024,  0.64175258,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.52087024,  0.77061856,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.52087024,  0.89948454,  0.48383024],
#        [ 0.49705882,  0.49986431,  0.52087024,  1.02835052,  0.48383024]])

# %%
scaled_sensitivity=pd.DataFrame(scaled_sensitivity, columns=['Porosity (%)', 'Acoustic impedance (kg/m2s*10^6)',
       'Brittleness Ratio', 'Vitrinite Reflectance (%)', 'Aroot(K)'])

# %%
scaled_sensitivity
# Out:
#     Porosity (%)  ...  Aroot(K)
# 0      -0.007143  ...   0.48383
# 1       0.076891  ...   0.48383
# 2       0.160924  ...   0.48383
# 3       0.244958  ...   0.48383
# 4       0.328992  ...   0.48383
# ..           ...  ...       ...
# 64      0.497059  ...   0.48383
# 65      0.497059  ...   0.48383
# 66      0.497059  ...   0.48383
# 67      0.497059  ...   0.48383
# 68      0.497059  ...   0.48383
#
# [69 rows x 5 columns]

# %%
y_scaled_sensitivity= scaled_sensitivity['Aroot(K)']
x_scaled_sensitivity= scaled_sensitivity.drop(['Aroot(K)'],axis=1)

x_scaled_sensitivity
# Out:
#     Porosity (%)  ...  Vitrinite Reflectance (%)
# 0      -0.007143  ...                   0.487113
# 1       0.076891  ...                   0.487113
# 2       0.160924  ...                   0.487113
# 3       0.244958  ...                   0.487113
# 4       0.328992  ...                   0.487113
# ..           ...  ...                        ...
# 64      0.497059  ...                   0.512887
# 65      0.497059  ...                   0.641753
# 66      0.497059  ...                   0.770619
# 67      0.497059  ...                   0.899485
# 68      0.497059  ...                   1.028351
#
# [69 rows x 4 columns]

# %%
y_scaled_sensitivity
# Out:
# 0     0.48383
# 1     0.48383
# 2     0.48383
# 3     0.48383
# 4     0.48383
#        ...
# 64    0.48383
# 65    0.48383
# 66    0.48383
# 67    0.48383
# 68    0.48383
# Name: Aroot(K), Length: 69, dtype: float64

# %%
y_pred_sensitivity=lm.predict(x_scaled_sensitivity)

# %%
y_pred_sensitivity
# Out:
# array([-0.05742901,  0.03246721,  0.12236342,  0.21225964,  0.30215585,
#         0.39205207,  0.48194828,  0.5718445 ,  0.66174071,  0.75163693,
#         0.84153314,  0.93142936,  1.02132557,  0.57138116,  0.56654695,
#         0.56171274,  0.55687853,  0.55204432,  0.54721011,  0.5423759 ,
#         0.53754169,  0.53270748,  0.52787327,  0.52303906,  0.51820485,
#         0.51337064,  0.50853643,  0.50370222,  0.49886801,  0.4940338 ,
#         0.4891996 ,  0.48436539,  0.47953118,  0.47469697,  0.46986276,
#         0.46502855,  0.46019434,  0.45536013,  0.45052592,  0.44569171,
#         0.4408575 ,  0.43602329,  0.43118908,  0.42635487,  0.42152066,
#         0.41668645,  0.41185224,  0.40701803,  0.40218382,  0.39734961,
#         0.25926621,  0.30767535,  0.3560845 ,  0.40449365,  0.45290279,
#         0.50131194,  0.54972109,  0.59813023,  0.64653938,  0.69494853,
#         0.36850216,  0.3983564 ,  0.42821064,  0.45806489,  0.48791913,
#         0.51777337,  0.54762761,  0.57748186,  0.6073361 ])

# %%
y_pred_sensitivity=pd.DataFrame(y_pred_sensitivity,columns=['Predicted Aroot(K)'])
y_pred_sensitivity
# Out:
#     Predicted Aroot(K)
# 0            -0.057429
# 1             0.032467
# 2             0.122363
# 3             0.212260
# 4             0.302156
# ..                 ...
# 64            0.487919
# 65            0.517773
# 66            0.547628
# 67            0.577482
# 68            0.607336
#
# [69 rows x 1 columns]

# %%
y_pred_sensitivity.to_csv('Predicted Aroot(K).csv')

# %%
df['Aroot(K)'].max()
# Out:
# 77.27073327

# %%
y_pred_sensitivity=y_pred_sensitivity['Predicted Aroot(K)']*(df['Aroot(K)'].max()-df['Aroot(K)'].min())+df['Aroot(K)'].min()
y_pred_sensitivity
# Out:
# 0     21.403716
# 1     26.153192
# 2     30.902668
# 3     35.652143
# 4     40.401619
#         ...
# 64    50.216028
# 65    51.793313
# 66    53.370599
# 67    54.947884
# 68    56.525170
# Name: Predicted Aroot(K), Length: 69, dtype: float64

# %%
plt.figure(figsize=(8,5))
por=np.linspace(4.5,16.5,13)
plt.scatter(por,y_pred_sensitivity.iloc[0:13])
plt.title('Porosity Impact on Aroot(K) Sensitivity')
plt.xlabel('Porosity (%)')
plt.ylabel('Aroot(K)')
# Out:
# Text(0, 0.5, 'Aroot(K)')

# %%
por=np.linspace(4.5,16.5,13)
por
# Out:
# array([ 4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5, 11.5, 12.5, 13.5, 14.5,
#        15.5, 16.5])

# %%
plt.figure(figsize=(8,5))
AI=np.linspace(1.4,5,37)
plt.scatter(AI,y_pred_sensitivity.iloc[13:50])
plt.title('AI Impact on Aroot(K) Sensitivity')
plt.xlabel('AI')
plt.ylabel('Aroot(K)')
# Out:
# Text(0, 0.5, 'Aroot(K)')

# %%
plt.figure(figsize=(8,5))
BR=np.linspace(13,101,10)
plt.scatter(BR,y_pred_sensitivity.iloc[50:60])
plt.title('BR Impact on Aroot(K) Sensitivity')
plt.xlabel('BR')
plt.ylabel('Aroot(K)')
# Out:
# Text(0, 0.5, 'Aroot(K)')

# %%
plt.figure(figsize=(8,5))
VR=np.linspace(0.74,2.34,9)
plt.scatter(VR,y_pred_sensitivity.iloc[60:69])
plt.title('VR Impact on Aroot(K) Sensitivity')
plt.xlabel('VR')
plt.ylabel('Aroot(K)')
# Out:
# Text(0, 0.5, 'Aroot(K)')
